# %% [markdown]
# # Analysis of MMNN group chat using Python

# %% [markdown]
# let's first import the libraries  to use

# %%
import matplotlib.pyplot as plt # for visualization
import numpy as np # for numerical 
import pandas as pd # for data analysis
from pandas.io.json import json_normalize # dealing with nested json files

# %%
data = pd.read_json("data.json")
data.head(5)
# Out:
#         name                type          id  \
# 0  MMNN Chat  private_supergroup  9894386197
# 1  MMNN Chat  private_supergroup  9894386197
# 2  MMNN Chat  private_supergroup  9894386197
# 3  MMNN Chat  private_supergroup  9894386197
# 4  MMNN Chat  private_supergroup  9894386197
#
#                                             messages
# 0  {'id': -999940249, 'type': 'service', 'date': ...
# 1  {'id': -999940248, 'type': 'service', 'date': ...
# 2  {'id': -999940247, 'type': 'message', 'date': ...
# 3  {'id': -999940246, 'type': 'service', 'date': ...
# 4  {'id': -999940245, 'type': 'service', 'date': ...

# %% [markdown]
# from the above data frame we can see that the data we need to deal with is nested inside another dictionary hence why we need the json_normalize import to create a dataframe of it's own

# %%
new = json_normalize(data["messages"])
new.head(4)
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.
#           id     type                 date      actor     actor_id  \
# 0 -999940249  service  2018-11-04T13:56:18      Meria  173882242.0
# 1 -999940248  service  2018-11-04T13:57:30       None  553243944.0
# 2 -999940247  message  2018-11-04T13:57:36        NaN          NaN
# 3 -999940246  service  2018-11-04T13:57:46  ZuluDelta  170733126.0
#
#                action      title  \
# 0        create_group  MMNN Chat
# 1  join_group_by_link        NaN
# 2                 NaN        NaN
# 3  join_group_by_link        NaN
#
#                                              members text inviter  ...  \
# 0  [Meria, King3way, Kotal Khan, Afro., BlackMamb...          NaN  ...
# 1                                                NaN        Meria  ...
# 2                                                NaN          NaN  ...
# 3                                                NaN        Meria  ...
#
#   location_information.latitude  location_information.longitude performer  \
# 0                           NaN                             NaN       NaN
# 1                           NaN                             NaN       NaN
# 2                           NaN                             NaN       NaN
# 3                           NaN                             NaN       NaN
#
#   game_title game_description game_link  game_message_id  score  place_name  \
# 0        NaN              NaN       NaN              NaN    NaN         NaN
# 1        NaN              NaN       NaN              NaN    NaN         NaN
# 2        NaN              NaN       NaN              NaN    NaN         NaN
# 3        NaN              NaN       NaN              NaN    NaN         NaN
#
#   address
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
#
# [4 rows x 44 columns]

# %%
new.tail(4)
# Out:
#             id     type                 date actor  actor_id action title  \
# 235583  283818  message  2020-07-17T23:25:18   NaN       NaN    NaN   NaN
# 235584  283819  message  2020-07-17T23:26:39   NaN       NaN    NaN   NaN
# 235585  283820  message  2020-07-17T23:27:10   NaN       NaN    NaN   NaN
# 235586  283821  message  2020-07-17T23:29:32   NaN       NaN    NaN   NaN
#
#        members                                               text inviter  \
# 235583     NaN  😂😂😂😂\n\nI would love to see what you two can k...     NaN
# 235584     NaN                                                        NaN
# 235585     NaN  [{'type': 'mention', 'text': '@dvorah55'},  is...     NaN
# 235586     NaN  Don't underestimate him, I kind of know what h...     NaN
#
#         ... location_information.latitude  location_information.longitude  \
# 235583  ...                           NaN                             NaN
# 235584  ...                           NaN                             NaN
# 235585  ...                           NaN                             NaN
# 235586  ...                           NaN                             NaN
#
#        performer game_title game_description game_link  game_message_id  \
# 235583       NaN        NaN              NaN       NaN              NaN
# 235584       NaN        NaN              NaN       NaN              NaN
# 235585       NaN        NaN              NaN       NaN              NaN
# 235586       NaN        NaN              NaN       NaN              NaN
#
#         score  place_name address
# 235583    NaN         NaN     NaN
# 235584    NaN         NaN     NaN
# 235585    NaN         NaN     NaN
# 235586    NaN         NaN     NaN
#
# [4 rows x 44 columns]

# %% [markdown]
# This new dataframe contains the data we need that we can analyze
